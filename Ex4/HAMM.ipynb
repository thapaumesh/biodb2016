# %%
def hamd(x, y):
    count = 0
    for ch1, ch2  in zip(x,y): 
        if ch1!=ch2:
            count = count + 1
                
    return count
dna1 = '...'
dna2 = '...'
hamd(dna1, dna2)
# Out:
# 466
