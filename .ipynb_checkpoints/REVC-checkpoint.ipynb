# %%
def revcomplement(dna):
    a = ''
    for i in dna:
        if i == 'A':
            a = a + 'T'
        elif i == 'T':
            a = a + 'A'
        elif i == 'C':
            a = a + 'G'
        elif i == 'G':
            a = a + 'C'
    return a[::-1]

dna = '...'
revcomplement(dna)
# Out:
# '...'
